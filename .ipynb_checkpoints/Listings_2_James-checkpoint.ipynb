# %% [markdown]
# # This is the minimum Working Example to compute a multiple scattering experiment in the Q-Phase

# %%
#!/usr/bin/env python2
# -*- coding: utf-8 -*-
"""
Created on Sat Jun 10 19:53:32 2017

@author: Bene

This file creates a fwd-model for the TESCAN Q-PHASE under 
multiple-scattering. It is majorly derived from  "LEarning approach for optical tomography"
U. S. Kamilov, BIG, EPFL, 2014.
"""
# %load_ext autoreload
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import h5py 
import scipy.io
import scipy as scipy
import scipy.misc

# load own functions
from src import tf_helper as helper
from src import muscat as mus
from src import tf_generate_object as tf_go
from src import data as data

# %% [markdown]
# # Define some optimization parameters

# %%
optimize = 0#0# want to optimize for the refractive index?

my_learningrate = 1e-3# learning rate
my_keep_prob = 1
tv_lambda = 1e-2
gr_lambda = 1e-2
obj_reg_lambda = 1e9

load_data = 0 # want to load previously stored data from disk (numpy) otherwise MATLAB experiment will be loaded    


# Define the location for the files; it is expected to be in the MATLAB -v7.3 format
# The parameter file has a struct-object called myParameter with all necessary variables
# The dataset file holds a complex matrix with Nx * Ny * Nz voxels called allAmpSimu
matlab_par_file = './Data/EM-James/Parameter.mat'   # File with the experimental Parameters
# matlab_val_file = './Data/BEADS/Beads_40x_100a_allAmp.mat'   # File that stores the 3D (complex) Amplitude

# %%
# This is the place to load data
''' File which stores the experimental parameters from the Q-PHASE setup 
    1.) Read in the parameters of the dataset ''' 
matlab_pars = data.import_parameters_mat(filename = matlab_par_file)
print
''' 2.) Read in the parameters of the dataset ''' 
# matlab_val = data.import_realdata_h5(filename = matlab_val_file, matname='allAmpSimu', is_complex=True)
# Out:
# ' 2.) Read in the parameters of the dataset '

# %% [markdown]
# # Initiate the MuScat (Multiple Scattering) Object

# %%
''' Create the Model'''
mm = mus.MuScatModel(matlab_pars, optimize, my_learningrate, my_keep_prob, tv_lambda, obj_reg_lambda, gr_lambda) # First initiliaze it
# Out:
# Assigned some value for dn which is not good!

# %% [markdown]
# ## Compute the System's properties (e.g. Pupil function/Illumination Source, K-vectors, etc.)

# %%
''' Compute the systems model'''
mm.computeSys()

# make sure, that the condenser's aperture is looking ok
plt.imshow(mm.Ic, cmap='gray')
# Out:
# I detected a darkfield illumination aperture!
# Number of Illumination Angles / Plane waves: 120

# %% [markdown]
# Now load data which has been saved previously (Optional!)

# %%
# Load Copute the systems model
#if(load_data):
#    mm.loadData()
#else:
#    mm.allSumAmp_mes = matlab_val

print('WARNING: TODO!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8a381e9bccc7> in <module>
#       3     mm.loadData()
#       4 else:
# ----> 5     mm.allSumAmp_mes = matlab_val
#
# NameError: name 'matlab_val' is not defined

# %% [markdown]
# ## Generate a phantom object in 3D

# %%
''' Create a 3D Refractive Index Distributaton as a artificial sample'''
obj = tf_go.generateObject(obj_shape=mm.mysize, obj_dim=mm.dx, obj_type = 1, diameter = 1, dn = mm.dn)

# %% [markdown]
# ## Create computational graph

# %%
''' Assign Object (3D sample) to Class'''
mm.obj_init = tf_go.generateInitObject(obj)

''' Create computational graph'''
mm.create_graph(obj, if_xla=0)
# Out:
# Start interactive Session
# no XLA activvated
# Generate Object
# Buildup Q-PHASE Model
# Current Z-Slice # is: 0
# Current illumination angle # is: 24
# Current illumination angle # is: 25
# Current illumination angle # is: 26
# Current illumination angle # is: 27
# Current illumination angle # is: 28
# Current illumination angle # is: 29
# Current illumination angle # is: 30
# Current illumination angle # is: 31
# Current illumination angle # is: 32
# Current illumination angle # is: 33
# Current illumination angle # is: 34
# Current illumination angle # is: 35
# Current illumination angle # is: 36
# Current illumination angle # is: 37
# Current illumination angle # is: 38
# Current illumination angle # is: 39
# Current illumination angle # is: 40
# Current illumination angle # is: 41
# Current illumination angle # is: 42
# Current illumination angle # is: 43
# Current illumination angle # is: 44
# Current illumination angle # is: 45
# Current illumination angle # is: 46
# Current illumination angle # is: 47
# Current illumination angle # is: 48
# Current illumination angle # is: 49
# Current illumination angle # is: 50
# Current illumination angle # is: 51
# Current illumination angle # is: 52
# Current illumination angle # is: 53
# Current illumination angle # is: 54
# Current illumination angle # is: 55
# Current illumination angle # is: 56
# Current illumination angle # is: 57
# Current illumination angle # is: 58
# Current illumination angle # is: 59
# Current illumination angle # is: 60
# Current illumination angle # is: 61
# Current illumination angle # is: 62
# Current illumination angle # is: 63
# Current illumination angle # is: 64
# Current illumination angle # is: 65
# Current illumination angle # is: 66
# Current illumination angle # is: 67
# Current illumination angle # is: 68
# Current illumination angle # is: 69
# Current illumination angle # is: 70
# Current illumination angle # is: 71
# Current illumination angle # is: 72
# Current illumination angle # is: 73
# Current illumination angle # is: 74
# Current illumination angle # is: 75
# Current illumination angle # is: 76
# Current illumination angle # is: 77
# Current illumination angle # is: 78
# Current illumination angle # is: 79
# Current illumination angle # is: 80
# Current illumination angle # is: 81
# Current illumination angle # is: 82
# Current illumination angle # is: 83
# Current illumination angle # is: 84
# Current illumination angle # is: 85
# Current illumination angle # is: 86
# Current illumination angle # is: 87
# Current illumination angle # is: 88
# Current illumination angle # is: 89
# Current illumination angle # is: 90
# Current illumination angle # is: 91
# Current illumination angle # is: 92
# Current illumination angle # is: 93
# Current illumination angle # is: 94
# Current illumination angle # is: 95
# Current illumination angle # is: 96
# Current illumination angle # is: 97
# Current illumination angle # is: 98
# Current illumination angle # is: 99
# Current illumination angle # is: 100
# Current illumination angle # is: 101
# Current illumination angle # is: 102
# Current illumination angle # is: 103
# Current illumination angle # is: 104
# Current illumination angle # is: 105
# Current illumination angle # is: 106
# Current illumination angle # is: 107
# Current illumination angle # is: 108
# Current illumination angle # is: 109
# Current illumination angle # is: 110
# Current illumination angle # is: 111
# Current illumination angle # is: 112
# Current illumination angle # is: 113
# Current illumination angle # is: 114
# Current illumination angle # is: 115
# Current illumination angle # is: 116
# Current illumination angle # is: 117
# Current illumination angle # is: 118
# Current illumination angle # is: 119
# Building the graph successfully

# %% [markdown]
# ## Now evaluate the result - start inference

# %%
'''Compute result'''    
mm.eval_graph() # result will be stored in mm.allSumAmp

# mm.inference(obj, if_xla=0)

# %% [markdown]
# ## Visualize Results

# %%
print(mm.allSumAmp.shape)
plt.imshow(np.abs(mm.allSumAmp[:,:,int(mm.Nx/2)]))
# mm.visualize_results()

# %% [markdown]
# # Add some Regularizers

# %%
mm.regularizer(if_tvreg=True, if_posreg=True)
